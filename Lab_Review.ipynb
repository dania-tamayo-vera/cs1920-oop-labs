# %% [markdown]
# # Lab Review - Files and Object Oriented Programming

# %% [markdown]
# ## Overview
# This lab reviews:
# 1. Reading text files
# 2. Reading CSV files
# 3. Writing files
# 4. Designing and improving classes
# 5. Creating a collection class
#
# Work step by step. Follow the instructions carefully.

# %% [markdown]
# ## Section 1 - Reading a Text File

# %% [markdown]
# You are given a file called `transactions.txt`.
#
# Tasks:
# 1. Open the file for reading
# 2. Count how many lines are in the file
# 3. Count how many times the word 'Deposit' appears
# 4. Print both results
#
# Do not modify the file content.

# %%
# Write your solution here

# %% [markdown]
# Expected format:
#
# Total lines: X
# Total deposits: Y

# %% [markdown]
# ## Section 2 - Writing a Summary File

# %% [markdown]
# Using the results from Section 1:
#
# 1. Create a new file called `summary.txt`
# 2. Write the number of lines and number of deposits into that file
# 3. Re-open the file and print its contents to confirm it was written correctly

# %%
# Write your solution here

# %% [markdown]
# ## Section 3 - Processing CSV Data

# %% [markdown]
# You are given a file called `sales.csv` with the following columns:
# product, quantity, price
#
# Tasks:
# 1. Open the file
# 2. Skip the header row
# 3. Compute the revenue for each row (quantity × price)
# 4. Compute total revenue
# 5. Print total revenue rounded to 2 decimal places

# %%
# Write your solution here

# %% [markdown]
# Expected format:
#
# Total revenue: XX.XX

# %% [markdown]
# ## Section 4 - Designing a LibraryAccount Class

# %% [markdown]
# You are designing a system for a small library.
#
# Create a class called `LibraryAccount`.
#
# Step 1: Constructor
# - Parameters: name, books_borrowed
# - Store them as instance variables
#
# Step 2: Methods
# - borrow_book() increases books_borrowed by 1
# - return_book() decreases books_borrowed by 1
# - display() prints the account name and number of borrowed books
#
# Step 3: Validation
# - books_borrowed should never go below 0
#
# Step 4: Testing
# - Create two objects
# - Call methods on both
# - Print results

# %%
# Write your LibraryAccount class and testing code here

# %% [markdown]
# ## Model Output - Section 4

# %% [markdown]
# ## Section 5 - Adding Class Variables and Static Methods

# %% [markdown]
# Enhance your LibraryAccount class:
#
# 1. Add a class variable that tracks total number of accounts created
# 2. Add a static method called library_policy() that returns a short string describing borrowing rules
# 3. Print the total number of accounts
# 4. Call the static method

# %%
# Copy your class and improve it here

# %% [markdown]
# ## Model Output - Section 5

# %% [markdown]
# ## Section 6 - Creating a LibrarySystem Class

# %% [markdown]
# Create a class called `LibrarySystem`.
#
# Requirements:
# - It stores multiple LibraryAccount objects in a list
# - Method add_account(account)
# - Method total_books() that returns total borrowed books across all accounts
# - Method find_max_account() that returns the account with the most borrowed books
#
# Test your implementation.

# %%
# Write your LibrarySystem class here

# %% [markdown]
# # END OF LAB
