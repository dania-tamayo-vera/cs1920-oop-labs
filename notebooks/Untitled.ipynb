# %%
# Setup for CS 1920 Lab 01

student_name = ""  # @param {type:"string"}
student_id = ""    # @param {type:"string"}

# !pip -q install git+https://github.com/dania-tamayo-vera/cs1920-oop-labs

from cs1920lib import example_checks
print("Setup complete")
for res in example_checks():
    print(res)
# Out:
# /bin/bash: pip: command not found
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       4 student_id = ""    # @param {type:"string"}
#       6 get_ipython().system('pip -q install git+https://github.com/dania-tamayo-vera/cs1920-oop-labs')
# ----> 8 from cs1920lib import example_checks
#       9 print("Setup complete")
#      10 for res in example_checks():
#
# ModuleNotFoundError: No module named 'cs1920lib'
