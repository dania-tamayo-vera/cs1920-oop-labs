# %%
# Setup for CS 1920 Lab 01 Test

student_name_1 = ""  # @param {type:"string"}
student_name_2 = ""  # @param {type:"string"}

# !pip install -q git+https://github.com/dania-tamayo-vera/cs1920-oop-labs

from cs1920lib import example_checks
print("Setup complete")

print(f"Student 1: {student_name_1}")
print(f"Student 2: {student_name_2}")

for res in example_checks():
    print(res)

# %% [markdown]
# ## Task
#
# Write a BankAccount class in Python.
#
# Requirements:
#
# 1. The constructor takes at least: owner and an optional starting balance (default 0).
# 2. There is a balance attribute that stores the current balance.
# 3. The method deposit(amount) increases the balance.
# 4. The method withdraw(amount) decreases the balance.
# 5. You should decide how to handle invalid amounts or overdraft. You can raise errors or print messages, but be consistent.
#
# After you write the class, run the self check cell to see basic tests.

# %%
# Design thinking – BankAccount

bank_account_design = """
Describe your BankAccount design in your own words.

1. Attributes
   List the data you will store in each account and their types.
   Example: owner (str), balance (float), overdraft_allowed (bool).

2. Invariants
   Write 2–3 rules that should always be true.
   Example: balance is never negative unless overdraft_allowed is True.

3. Methods
   List the methods your class will have and what they do.
   At minimum: deposit(amount), withdraw(amount).
   You can also plan __repr__ or helper methods if you like.

4. Contracts
   For deposit(amount) and withdraw(amount):
   - Preconditions: what must be true before you call the method.
   - Postconditions: what must be true after it finishes.

Keep this as plain text, not code. Use short sentences or bullet points.
"""

print("Your design description is stored in bank_account_design.")
# Out:
# Your design description is stored in bank_account_design.

# %%
# Student code - implement BankAccount here
# Do not change the class name

class BankAccount:
    def __init__(self, owner, balance=0.0):
        # TODO: store owner and balance
        # You can add extra attributes if you want
        self.owner = owner


    def deposit(self, amount):
        # TODO: increase balance
        # You may want to check that amount is positive
    

    def withdraw(self, amount):
        # TODO: decrease balance
        # You may want to prevent going negative


    def __repr__(self):
        return f"BankAccount(owner={self.owner!r}, balance={self.balance})"

# %%
# Self checks for BankAccount

from cs1920lib import lab01_public_checks

results = lab01_public_checks(BankAccount)
for r in results:
    print(r)
